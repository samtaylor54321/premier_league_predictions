# %%
import lightgbm as lgb
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import pathlib
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn import metrics
from sklearn.datasets import load_breast_cancer
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from scipy.stats import uniform as sp_uniform
import sklearn.metrics
from lightgbm import LGBMClassifier

# %%
# Parse results data
results = pd.DataFrame()

for path in pathlib.Path('/Users/sam/Documents/projects/premier_league_predictions/data').rglob("*.csv"):
    data = pd.read_csv(path)
    results = pd.concat([results, data])
    
# Remove missing values    
results = results[results.result.values != 'pp']
results = results[~pd.isnull(results.result.values)]
results = results.drop(['Unnamed: 0'], axis=1)

# %%
X = results.loc[:, results.columns != 'result'].values
y = results.iloc[:, -1].values

# %%
y_values = []

for value in y:
    if value == "home":
        y_values.append(0)
    elif value == "away":
        y_values.append(1)
    else:
        y_values.append(2)
        
y = y_values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=True)

# %%
parameters={"early_stopping_rounds":20, 
            "eval_metric" : 'multi_logloss', 
            "eval_set" : [(X_test,y_test)],
            'eval_names': ['valid'],
            'verbose': 100,
            'categorical_feature': 'auto'}

# %%
parameter_tuning ={
             'max_depth': sp_randint(1,3),
             'num_leaves': sp_randint(1, 4), 
             'learning_rate ': [0.1,0.01,0.001],
             'min_child_samples': sp_randint(20, 50), 
             'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
             'subsample': sp_uniform(loc=0.2, scale=0.8), 
             'colsample_bytree': sp_uniform(loc=0.4, scale=0.6),
             'reg_alpha': [0, 1e-1, 1, 2, 5, 7, 10, 50, 100],
             'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 50, 100]}

# %%
scorer = sklearn.metrics.make_scorer(sklearn.metrics.f1_score, average = 'weighted')

# %%
classifier = LGBMClassifier(random_state=300, silent=True, metric='None', n_jobs=4, n_estimators=5000)

find_parameters = RandomizedSearchCV(
    estimator=classifier, param_distributions=parameter_tuning, 
    n_iter=100,
    scoring=scorer,
    cv=5,
    refit=True,
    random_state=300,
    verbose=False)

# %%
find_parameters.fit(X_train, y_train, **parameters)
print('Best score : {} with parameters: {} '.format(find_parameters.best_score_, find_parameters.best_params_))
# Out:
# Training until validation scores don't improve for 20 rounds
# [100]	valid's multi_logloss: 1.12763
# [200]	valid's multi_logloss: 1.12759
# [300]	valid's multi_logloss: 1.12759
# [400]	valid's multi_logloss: 1.12759
# [500]	valid's multi_logloss: 1.12759
# [600]	valid's multi_logloss: 1.12759
# Early stopping, best iteration is:
# [613]	valid's multi_logloss: 1.12759
# Training until validation scores don't improve for 20 rounds
# [100]	valid's multi_logloss: 1.10862
# [200]	valid's multi_logloss: 1.10841
# [300]	valid's multi_logloss: 1.1084
# [400]	valid's multi_logloss: 1.1084
# [500]	valid's multi_logloss: 1.1084
# Early stopping, best iteration is:
# [528]	valid's multi_logloss: 1.1084
# Training until validation scores don't improve for 20 rounds
# [100]	valid's multi_logloss: 1.1093
# [200]	valid's multi_logloss: 1.1091
# [300]	valid's multi_logloss: 1.1091
# [400]	valid's multi_logloss: 1.1091
# [500]	valid's multi_logloss: 1.1091
# Early stopping, best iteration is:
# [517]	valid's multi_logloss: 1.1091
# Training until validation scores don't improve for 20 rounds
# [100]	valid's multi_logloss: 1.1099
# [200]	valid's multi_logloss: 1.10975
# [300]	valid's multi_logloss: 1.10975
# [400]	valid's multi_logloss: 1.10975
# [500]	valid's multi_logloss: 1.10975
# Early stopping, best iteration is:
# [548]	valid's multi_logloss: 1.10975
# Training until validation scores don't improve for 20 rounds
# [100]	valid's multi_logloss: 1.11722
# [200]	valid's multi_logloss: 1.11721
# [300]	valid's multi_logloss: 1.11721
# [400]	valid's multi_logloss: 1.11721
# Early stopping, best iteration is:
# [477]	valid's multi_logloss: 1.11721
# Training until validation scores don't improve for 20 rounds
# [100]	valid's multi_logloss: 1.19028
# [200]	valid's multi_logloss: 1.18513
# [300]	valid's multi_logloss: 1.18482
# [400]	valid's multi_logloss: 1.1848
# [500]	valid's multi_logloss: 1.1848
# [600]	valid's multi_logloss: 1.1848
# [700]	valid's multi_logloss: 1.1848
# Early stopping, best iteration is:
# [708]	valid's multi_logloss: 1.1848
# Training until validation scores don't improve for 20 rounds
# [100]	valid's multi_logloss: 1.1496
# [200]	valid's multi_logloss: 1.09188
# [300]	valid's multi_logloss: 1.07889
# [400]	valid's multi_logloss: 1.07717
# [500]	valid's multi_logloss: 1.07691
# [600]	valid's multi_logloss: 1.07687
# [700]	valid's multi_logloss: 1.07686
# [800]	valid's multi_logloss: 1.07686
# /Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1714, in __init__
#     train_set.construct().handle,
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1085, in construct
#     categorical_feature=self.categorical_feature, params=self.params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 887, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 937, in __init_from_np2d
#     ctypes.byref(self.handle)))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 805, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 600, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 234, in train
#     train_set._reverse_update_params()
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1181, in _reverse_update_params
#     _safe_call(_LIB.LGBM_DatasetUpdateParam(self.handle, c_str(param_dict_to_str(self.params))))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
#   FitFailedWarning)
# /Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1714, in __init__
#     train_set.construct().handle,
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1085, in construct
#     categorical_feature=self.categorical_feature, params=self.params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 887, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 937, in __init_from_np2d
#     ctypes.byref(self.handle)))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 805, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 600, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 234, in train
#     train_set._reverse_update_params()
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1181, in _reverse_update_params
#     _safe_call(_LIB.LGBM_DatasetUpdateParam(self.handle, c_str(param_dict_to_str(self.params))))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
#   FitFailedWarning)
# /Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1714, in __init__
#     train_set.construct().handle,
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1085, in construct
#     categorical_feature=self.categorical_feature, params=self.params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 887, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 937, in __init_from_np2d
#     ctypes.byref(self.handle)))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 805, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 600, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 234, in train
#     train_set._reverse_update_params()
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1181, in _reverse_update_params
#     _safe_call(_LIB.LGBM_DatasetUpdateParam(self.handle, c_str(param_dict_to_str(self.params))))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
#   FitFailedWarning)
# /Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1714, in __init__
#     train_set.construct().handle,
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1085, in construct
#     categorical_feature=self.categorical_feature, params=self.params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 887, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 937, in __init_from_np2d
#     ctypes.byref(self.handle)))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 805, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 600, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 234, in train
#     train_set._reverse_update_params()
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1181, in _reverse_update_params
#     _safe_call(_LIB.LGBM_DatasetUpdateParam(self.handle, c_str(param_dict_to_str(self.params))))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
#   FitFailedWarning)
# /Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1714, in __init__
#     train_set.construct().handle,
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1085, in construct
#     categorical_feature=self.categorical_feature, params=self.params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 887, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 937, in __init_from_np2d
#     ctypes.byref(self.handle)))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 805, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 600, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 234, in train
#     train_set._reverse_update_params()
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1181, in _reverse_update_params
#     _safe_call(_LIB.LGBM_DatasetUpdateParam(self.handle, c_str(param_dict_to_str(self.params))))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
#   FitFailedWarning)
# [900]	valid's multi_logloss: 1.07686
# [1000]	valid's multi_logloss: 1.07686
# [1100]	valid's multi_logloss: 1.07686
# Early stopping, best iteration is:
# [1147]	valid's multi_logloss: 1.07686
# Training until validation scores don't improve for 20 rounds
# [100]	valid's multi_logloss: 1.14725
# [200]	valid's multi_logloss: 1.08305
# [300]	valid's multi_logloss: 1.0753
# [400]	valid's multi_logloss: 1.07465
# [500]	valid's multi_logloss: 1.07459
# [600]	valid's multi_logloss: 1.07459
# [700]	valid's multi_logloss: 1.07459
# [800]	valid's multi_logloss: 1.07459
# [900]	valid's multi_logloss: 1.07459
# Early stopping, best iteration is:
# [959]	valid's multi_logloss: 1.07459
# Training until validation scores don't improve for 20 rounds
# [100]	valid's multi_logloss: 1.15053
# [200]	valid's multi_logloss: 1.13246
# [300]	valid's multi_logloss: 1.13141
# [400]	valid's multi_logloss: 1.1313
# [500]	valid's multi_logloss: 1.13128
# [600]	valid's multi_logloss: 1.13128
# [700]	valid's multi_logloss: 1.13128
# [800]	valid's multi_logloss: 1.13128
# [900]	valid's multi_logloss: 1.13128
# Early stopping, best iteration is:
# [913]	valid's multi_logloss: 1.13128
# Training until validation scores don't improve for 20 rounds
# [100]	valid's multi_logloss: 1.16341
# [200]	valid's multi_logloss: 1.12665
# [300]	valid's multi_logloss: 1.12399
# [400]	valid's multi_logloss: 1.12379
# [500]	valid's multi_logloss: 1.12378
# [600]	valid's multi_logloss: 1.12378
# [700]	valid's multi_logloss: 1.12378
# [800]	valid's multi_logloss: 1.12378
# Early stopping, best iteration is:
# [810]	valid's multi_logloss: 1.12378
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [3]	valid's multi_logloss: 1.12924
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.11611
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.11611
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.11611
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.12118
# Training until validation scores don't improve for 20 rounds
# [100]	valid's multi_logloss: 1.10907
# [200]	valid's multi_logloss: 1.10572
# [300]	valid's multi_logloss: 1.10508
# [400]	valid's multi_logloss: 1.10497
# [500]	valid's multi_logloss: 1.10495
# [600]	valid's multi_logloss: 1.10495
# [700]	valid's multi_logloss: 1.10495
# [800]	valid's multi_logloss: 1.10495
# [900]	valid's multi_logloss: 1.10495
# [1000]	valid's multi_logloss: 1.10495
# [1100]	valid's multi_logloss: 1.10495
# Early stopping, best iteration is:
# [1151]	valid's multi_logloss: 1.10495
# Training until validation scores don't improve for 20 rounds
# [100]	valid's multi_logloss: 1.09903
# [200]	valid's multi_logloss: 1.09825
# [300]	valid's multi_logloss: 1.09816
# [400]	valid's multi_logloss: 1.09815
# [500]	valid's multi_logloss: 1.09815
# [600]	valid's multi_logloss: 1.09815
# [700]	valid's multi_logloss: 1.09815
# [800]	valid's multi_logloss: 1.09815
# Early stopping, best iteration is:
# [861]	valid's multi_logloss: 1.09815
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [32]	valid's multi_logloss: 1.21114
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [33]	valid's multi_logloss: 1.21084
# Training until validation scores don't improve for 20 rounds
# [100]	valid's multi_logloss: 1.21147
# [200]	valid's multi_logloss: 1.21047
# [300]	valid's multi_logloss: 1.21045
# [400]	valid's multi_logloss: 1.21045
# [500]	valid's multi_logloss: 1.21045
# [600]	valid's multi_logloss: 1.21045
# Early stopping, best iteration is:
# [672]	valid's multi_logloss: 1.21045
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [2]	valid's multi_logloss: 1.09169
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [24]	valid's multi_logloss: 1.06716
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [8]	valid's multi_logloss: 1.0659
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [5]	valid's multi_logloss: 1.0739
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [5]	valid's multi_logloss: 1.06942
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.12924
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.11611
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.11611
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.11611
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.12118
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [10]	valid's multi_logloss: 1.0919
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [52]	valid's multi_logloss: 1.05777
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [8]	valid's multi_logloss: 1.0685
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [6]	valid's multi_logloss: 1.07742
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [11]	valid's multi_logloss: 1.06909
# /Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1714, in __init__
#     train_set.construct().handle,
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1085, in construct
#     categorical_feature=self.categorical_feature, params=self.params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 887, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 937, in __init_from_np2d
#     ctypes.byref(self.handle)))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 805, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 600, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 234, in train
#     train_set._reverse_update_params()
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1181, in _reverse_update_params
#     _safe_call(_LIB.LGBM_DatasetUpdateParam(self.handle, c_str(param_dict_to_str(self.params))))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
#   FitFailedWarning)
# /Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1714, in __init__
#     train_set.construct().handle,
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1085, in construct
#     categorical_feature=self.categorical_feature, params=self.params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 887, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 937, in __init_from_np2d
#     ctypes.byref(self.handle)))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 805, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 600, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 234, in train
#     train_set._reverse_update_params()
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1181, in _reverse_update_params
#     _safe_call(_LIB.LGBM_DatasetUpdateParam(self.handle, c_str(param_dict_to_str(self.params))))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
#   FitFailedWarning)
# /Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1714, in __init__
#     train_set.construct().handle,
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1085, in construct
#     categorical_feature=self.categorical_feature, params=self.params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 887, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 937, in __init_from_np2d
#     ctypes.byref(self.handle)))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 805, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 600, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 234, in train
#     train_set._reverse_update_params()
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1181, in _reverse_update_params
#     _safe_call(_LIB.LGBM_DatasetUpdateParam(self.handle, c_str(param_dict_to_str(self.params))))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
#   FitFailedWarning)
# /Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1714, in __init__
#     train_set.construct().handle,
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1085, in construct
#     categorical_feature=self.categorical_feature, params=self.params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 887, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 937, in __init_from_np2d
#     ctypes.byref(self.handle)))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 805, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 600, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 234, in train
#     train_set._reverse_update_params()
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1181, in _reverse_update_params
#     _safe_call(_LIB.LGBM_DatasetUpdateParam(self.handle, c_str(param_dict_to_str(self.params))))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
#   FitFailedWarning)
# /Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1714, in __init__
#     train_set.construct().handle,
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1085, in construct
#     categorical_feature=self.categorical_feature, params=self.params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 887, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 937, in __init_from_np2d
#     ctypes.byref(self.handle)))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 805, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 600, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 234, in train
#     train_set._reverse_update_params()
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1181, in _reverse_update_params
#     _safe_call(_LIB.LGBM_DatasetUpdateParam(self.handle, c_str(param_dict_to_str(self.params))))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
#   FitFailedWarning)
# /Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1714, in __init__
#     train_set.construct().handle,
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1085, in construct
#     categorical_feature=self.categorical_feature, params=self.params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 887, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 937, in __init_from_np2d
#     ctypes.byref(self.handle)))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 805, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 600, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 234, in train
#     train_set._reverse_update_params()
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1181, in _reverse_update_params
#     _safe_call(_LIB.LGBM_DatasetUpdateParam(self.handle, c_str(param_dict_to_str(self.params))))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
#   FitFailedWarning)
# /Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1714, in __init__
#     train_set.construct().handle,
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1085, in construct
#     categorical_feature=self.categorical_feature, params=self.params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 887, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 937, in __init_from_np2d
#     ctypes.byref(self.handle)))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 805, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 600, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 234, in train
#     train_set._reverse_update_params()
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1181, in _reverse_update_params
#     _safe_call(_LIB.LGBM_DatasetUpdateParam(self.handle, c_str(param_dict_to_str(self.params))))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
#   FitFailedWarning)
# /Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1714, in __init__
#     train_set.construct().handle,
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1085, in construct
#     categorical_feature=self.categorical_feature, params=self.params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 887, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 937, in __init_from_np2d
#     ctypes.byref(self.handle)))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 805, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 600, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 234, in train
#     train_set._reverse_update_params()
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1181, in _reverse_update_params
#     _safe_call(_LIB.LGBM_DatasetUpdateParam(self.handle, c_str(param_dict_to_str(self.params))))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
#   FitFailedWarning)
# /Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1714, in __init__
#     train_set.construct().handle,
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1085, in construct
#     categorical_feature=self.categorical_feature, params=self.params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 887, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 937, in __init_from_np2d
#     ctypes.byref(self.handle)))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 805, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 600, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 234, in train
#     train_set._reverse_update_params()
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1181, in _reverse_update_params
#     _safe_call(_LIB.LGBM_DatasetUpdateParam(self.handle, c_str(param_dict_to_str(self.params))))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
#   FitFailedWarning)
# /Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1714, in __init__
#     train_set.construct().handle,
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1085, in construct
#     categorical_feature=self.categorical_feature, params=self.params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 887, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 937, in __init_from_np2d
#     ctypes.byref(self.handle)))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 805, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 600, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 234, in train
#     train_set._reverse_update_params()
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1181, in _reverse_update_params
#     _safe_call(_LIB.LGBM_DatasetUpdateParam(self.handle, c_str(param_dict_to_str(self.params))))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
#   FitFailedWarning)
# /Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1714, in __init__
#     train_set.construct().handle,
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1085, in construct
#     categorical_feature=self.categorical_feature, params=self.params)
# ...
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 887, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 937, in __init_from_np2d
#     ctypes.byref(self.handle)))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 805, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 600, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 234, in train
#     train_set._reverse_update_params()
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1181, in _reverse_update_params
#     _safe_call(_LIB.LGBM_DatasetUpdateParam(self.handle, c_str(param_dict_to_str(self.params))))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
#   FitFailedWarning)
# /Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1714, in __init__
#     train_set.construct().handle,
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1085, in construct
#     categorical_feature=self.categorical_feature, params=self.params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 887, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 937, in __init_from_np2d
#     ctypes.byref(self.handle)))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 805, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 600, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 234, in train
#     train_set._reverse_update_params()
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1181, in _reverse_update_params
#     _safe_call(_LIB.LGBM_DatasetUpdateParam(self.handle, c_str(param_dict_to_str(self.params))))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
#   FitFailedWarning)
# /Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1714, in __init__
#     train_set.construct().handle,
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1085, in construct
#     categorical_feature=self.categorical_feature, params=self.params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 887, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 937, in __init_from_np2d
#     ctypes.byref(self.handle)))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 805, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 600, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 234, in train
#     train_set._reverse_update_params()
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1181, in _reverse_update_params
#     _safe_call(_LIB.LGBM_DatasetUpdateParam(self.handle, c_str(param_dict_to_str(self.params))))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
#   FitFailedWarning)
# /Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1714, in __init__
#     train_set.construct().handle,
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1085, in construct
#     categorical_feature=self.categorical_feature, params=self.params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 887, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 937, in __init_from_np2d
#     ctypes.byref(self.handle)))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 805, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 600, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 234, in train
#     train_set._reverse_update_params()
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1181, in _reverse_update_params
#     _safe_call(_LIB.LGBM_DatasetUpdateParam(self.handle, c_str(param_dict_to_str(self.params))))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
#   FitFailedWarning)
# /Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1714, in __init__
#     train_set.construct().handle,
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1085, in construct
#     categorical_feature=self.categorical_feature, params=self.params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 887, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 937, in __init_from_np2d
#     ctypes.byref(self.handle)))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 805, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/sklearn.py", line 600, in fit
#     callbacks=callbacks)
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py", line 234, in train
#     train_set._reverse_update_params()
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 1181, in _reverse_update_params
#     _safe_call(_LIB.LGBM_DatasetUpdateParam(self.handle, c_str(param_dict_to_str(self.params))))
#   File "/Users/sam/opt/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py", line 45, in _safe_call
#     raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
# lightgbm.basic.LightGBMError: Check failed: num_leaves >1 at /Users/runner/runners/2.160.1/work/1/s/python-package/compile/src/io/config_auto.cpp, line 304 .
#
#
#   FitFailedWarning)
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.11611
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.11611
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.12118
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [9]	valid's multi_logloss: 1.12924
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.11611
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.11611
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.11611
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.12118
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [63]	valid's multi_logloss: 1.08943
# Training until validation scores don't improve for 20 rounds
# [100]	valid's multi_logloss: 1.06438
# [200]	valid's multi_logloss: 1.05589
# [300]	valid's multi_logloss: 1.04906
# [400]	valid's multi_logloss: 1.04358
# [500]	valid's multi_logloss: 1.04222
# Early stopping, best iteration is:
# [501]	valid's multi_logloss: 1.04215
# Training until validation scores don't improve for 20 rounds
# [100]	valid's multi_logloss: 1.06706
# Early stopping, best iteration is:
# [119]	valid's multi_logloss: 1.06682
# Training until validation scores don't improve for 20 rounds
# [100]	valid's multi_logloss: 1.0666
# Early stopping, best iteration is:
# [176]	valid's multi_logloss: 1.06223
# Training until validation scores don't improve for 20 rounds
# [100]	valid's multi_logloss: 1.06511
# Early stopping, best iteration is:
# [122]	valid's multi_logloss: 1.06441
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [15]	valid's multi_logloss: 1.21646
# Best score : 0.3724196894283483 with parameters: {'colsample_bytree': 0.5834803063086598, 'learning_rate ': 0.001, 'max_depth': 2, 'min_child_samples': 44, 'min_child_weight': 0.1, 'num_leaves': 2, 'reg_alpha': 7, 'reg_lambda': 0.1, 'subsample': 0.5937222974453096}
# /Users/sam/opt/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_search.py:921: UserWarning: One or more of the test scores are non-finite: [0.24970132        nan 0.22235794 0.23218409 0.37241969 0.29060775
#         nan 0.23218409        nan        nan 0.29387624        nan
#  0.32088103 0.23218409        nan        nan        nan 0.23218409
#  0.32357024 0.23218409 0.28753914 0.23218409 0.3052926  0.23218409
#  0.32210091 0.24970132 0.32225827 0.23218409        nan 0.23218409
#  0.30834093        nan        nan 0.31574527        nan 0.23380338
#         nan 0.33082547        nan 0.23218409        nan 0.33348602
#         nan 0.16914856 0.23218409 0.23218409 0.24970132 0.32201116
#         nan 0.32204329        nan        nan 0.23218409 0.23218409
#  0.23218409 0.32715584 0.24970132        nan 0.32325652 0.23218409
#         nan        nan        nan        nan        nan 0.23218409
#         nan 0.28773348 0.27470052 0.23218409        nan        nan
#  0.23218409        nan        nan 0.32794693 0.23218409 0.33559136
#         nan        nan 0.32593943        nan        nan 0.32046785
#         nan        nan 0.23218409 0.24970132 0.32510632        nan
#  0.23218409 0.23218409 0.23218409 0.23218409 0.23218409        nan
#         nan        nan        nan 0.32204329]
#   category=UserWarning

# %%
best_parameters = find_parameters.best_params_
best_parameters
# Out:
# {'colsample_bytree': 0.5834803063086598,
#  'learning_rate ': 0.001,
#  'max_depth': 2,
#  'min_child_samples': 44,
#  'min_child_weight': 0.1,
#  'num_leaves': 2,
#  'reg_alpha': 7,
#  'reg_lambda': 0.1,
#  'subsample': 0.5937222974453096}

# %%
best_parameters_model = lgb.LGBMClassifier(**best_parameters)
best_parameters_model.set_params(**best_parameters)
# Out:
# LGBMClassifier(colsample_bytree=0.5834803063086598, learning_rate =0.001,
#                max_depth=2, min_child_samples=44, min_child_weight=0.1,
#                num_leaves=2, reg_alpha=7, reg_lambda=0.1,
#                subsample=0.5937222974453096)

# %%
clf = best_parameters_model.fit(X_train, y_train)

# %%
y_preds = clf.predict(X_test)

# %%
np.mean(np.asarray(y_test) == y_preds)
# Out:
# 0.4878048780487805

# %%
np.mean(np.asarray(y_test) == 0)
# Out:
# 0.4634146341463415

# %%
this_week = pd.read_csv("/Users/sam/Documents/projects/premier_league_predictions/current_gameweek.csv", index_col=0)

# %%
preds = []

for result in clf.predict(this_week.values):
    if result == 0:
        preds.append("home")
    elif result == 1:
        preds.append("away")
    else:
        preds.append("draw")
    
preds
# Out:
# ['home',
#  'home',
#  'draw',
#  'draw',
#  'home',
#  'draw',
#  'draw',
#  'draw',
#  'draw',
#  'home']

# %%
X = dataset.loc[:, dataset.columns != 'result'].values
y = dataset.iloc[:, -1].values
